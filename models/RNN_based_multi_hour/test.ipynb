# %%
import data_adapter
datapter = data_adapter.DataAdapter(data_dir = './test_data')

# %%
from data_adapter import DataAdapter

adapter = DataAdapter(
    data_dir="./test_data",
    y_column="compute_log_return_y",
    prediction_horizon=1
)

train_df, forecast_input, model_config = adapter.run()
# Out:
# ============================================================
# STEP 1: Read feature dictionary
# ============================================================
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       1 from data_adapter import DataAdapter
#       3 adapter = DataAdapter(
#       4     data_dir="./test_data",
#       5     y_column="compute_log_return_y",
#       6     prediction_horizon=1
#       7 )
# ----> 9 train_df, forecast_input, model_config = adapter.run()
#
# File ~/Documents/GitHub/AI_trading_system/models/RNN_based_multi_hour/data_adapter.py:77, in DataAdapter.run(self)
#      74 print("=" * 60)
#      76 dict_path = os.path.join(self.data_dir, "features", "feature_dictionary.json")
# ---> 77 with open(dict_path, 'r') as f:
#      78     self.feature_dict = json.load(f)
#      80 # Get tickers and label each with number
#
# FileNotFoundError: [Errno 2] No such file or directory: './test_data/features/feature_dictionary.json'
