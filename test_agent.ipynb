# %% [markdown]
# test data agent

# %%
# !python test/test_data_agent.py
# Out:
# 2025-12-22 19:31:02,128 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# ============================================================
# Testing Data Agent
# ============================================================
# ✓ Agent initialized
#
# Date range: 2024-01-01 to 2024-12-19 (~3 years)
# This will be fetched in 1-year chunks
#
# Running data collection...
# 2025-12-22 19:31:02,739 - agents.data_agent - INFO - No local data for AAPL, fetching full range
# 2025-12-22 19:31:02,740 - agents.data_agent - INFO - Fetching AAPL in 1 chunk(s)
# 2025-12-22 19:31:02,740 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:03,389 - agents.data_agent - INFO - Fetched 1700 hourly bars for AAPL
# 2025-12-22 19:31:03,429 - agents.data_agent - INFO - No local data for MSFT, fetching full range
# 2025-12-22 19:31:03,430 - agents.data_agent - INFO - Fetching MSFT in 1 chunk(s)
# 2025-12-22 19:31:03,430 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:03,577 - agents.data_agent - INFO - Fetched 1700 hourly bars for MSFT
# 2025-12-22 19:31:03,581 - agents.data_agent - INFO - No local data for JPM, fetching full range
# 2025-12-22 19:31:03,581 - agents.data_agent - INFO - Fetching JPM in 1 chunk(s)
# 2025-12-22 19:31:03,581 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:03,717 - agents.data_agent - INFO - Fetched 1700 hourly bars for JPM
# 2025-12-22 19:31:03,719 - agents.data_agent - INFO - No local data for XOM, fetching full range
# 2025-12-22 19:31:03,719 - agents.data_agent - INFO - Fetching XOM in 1 chunk(s)
# 2025-12-22 19:31:03,720 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:03,960 - agents.data_agent - INFO - Fetched 1700 hourly bars for XOM
# 2025-12-22 19:31:03,962 - agents.data_agent - INFO - No local data for JNJ, fetching full range
# 2025-12-22 19:31:03,962 - agents.data_agent - INFO - Fetching JNJ in 1 chunk(s)
# 2025-12-22 19:31:03,962 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:04,107 - agents.data_agent - INFO - Fetched 1700 hourly bars for JNJ
# 2025-12-22 19:31:04,109 - agents.data_agent - INFO - No local data for SPY, fetching full range
# 2025-12-22 19:31:04,110 - agents.data_agent - INFO - Fetching SPY in 1 chunk(s)
# 2025-12-22 19:31:04,110 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:04,259 - agents.data_agent - INFO - Fetched 1700 hourly bars for SPY
# 2025-12-22 19:31:04,262 - agents.data_agent - INFO - No local data for QQQ, fetching full range
# 2025-12-22 19:31:04,262 - agents.data_agent - INFO - Fetching QQQ in 1 chunk(s)
# 2025-12-22 19:31:04,262 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:04,414 - agents.data_agent - INFO - Fetched 1700 hourly bars for QQQ
# 2025-12-22 19:31:04,417 - agents.data_agent - INFO - No local data for IWM, fetching full range
# 2025-12-22 19:31:04,417 - agents.data_agent - INFO - Fetching IWM in 1 chunk(s)
# 2025-12-22 19:31:04,417 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:04,748 - agents.data_agent - INFO - Fetched 1700 hourly bars for IWM
# 2025-12-22 19:31:04,751 - agents.data_agent - INFO - No local data for ^VIX, fetching full range
# 2025-12-22 19:31:04,751 - agents.data_agent - INFO - Fetching ^VIX in 1 chunk(s)
# 2025-12-22 19:31:04,751 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:05,133 - agents.data_agent - INFO - Fetched 1465 hourly bars for ^VIX
# 2025-12-22 19:31:05,397 - agents.data_agent - INFO - Fetched fundamentals for AAPL
# 2025-12-22 19:31:05,594 - agents.data_agent - INFO - Fetched fundamentals for MSFT
# 2025-12-22 19:31:05,777 - agents.data_agent - INFO - Fetched fundamentals for JPM
# 2025-12-22 19:31:05,999 - agents.data_agent - INFO - Fetched fundamentals for XOM
# 2025-12-22 19:31:06,226 - agents.data_agent - INFO - Fetched fundamentals for JNJ
# 2025-12-22 19:31:06,226 - agents.data_agent - INFO - No local data for XLK, fetching full range
# 2025-12-22 19:31:06,226 - agents.data_agent - INFO - Fetching XLK in 1 chunk(s)
# 2025-12-22 19:31:06,226 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:06,421 - agents.data_agent - INFO - Fetched 1700 hourly bars for XLK
# 2025-12-22 19:31:06,425 - agents.data_agent - INFO - No local data for XLF, fetching full range
# 2025-12-22 19:31:06,425 - agents.data_agent - INFO - Fetching XLF in 1 chunk(s)
# 2025-12-22 19:31:06,425 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:06,598 - agents.data_agent - INFO - Fetched 1700 hourly bars for XLF
# 2025-12-22 19:31:06,601 - agents.data_agent - INFO - No local data for XLE, fetching full range
# 2025-12-22 19:31:06,601 - agents.data_agent - INFO - Fetching XLE in 1 chunk(s)
# 2025-12-22 19:31:06,601 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:06,797 - agents.data_agent - INFO - Fetched 1700 hourly bars for XLE
# 2025-12-22 19:31:06,800 - agents.data_agent - INFO - No local data for XLV, fetching full range
# 2025-12-22 19:31:06,800 - agents.data_agent - INFO - Fetching XLV in 1 chunk(s)
# 2025-12-22 19:31:06,800 - agents.data_agent - INFO -   Fetching chunk: 2024-01-01 to 2024-12-19
# 2025-12-22 19:31:06,955 - agents.data_agent - INFO - Fetched 1700 hourly bars for XLV
# 2025-12-22 19:31:07,052 - agents.data_agent - INFO - Fetched fundamentals for AAPL
# 2025-12-22 19:31:07,190 - agents.data_agent - INFO - Fetched fundamentals for MSFT
# 2025-12-22 19:31:07,324 - agents.data_agent - INFO - Fetched fundamentals for JPM
# 2025-12-22 19:31:07,458 - agents.data_agent - INFO - Fetched fundamentals for XOM
# 2025-12-22 19:31:07,547 - agents.data_agent - INFO - Fetched fundamentals for JNJ
# 2025-12-22 19:31:07,640 - agents.data_agent - INFO - Fetched company profile for AAPL
# 2025-12-22 19:31:07,675 - agents.data_agent - INFO - Fetched company profile for MSFT
# 2025-12-22 19:31:07,718 - agents.data_agent - INFO - Fetched company profile for JPM
# 2025-12-22 19:31:07,748 - agents.data_agent - INFO - Fetched company profile for XOM
# 2025-12-22 19:31:07,790 - agents.data_agent - INFO - Fetched company profile for JNJ
# 2025-12-22 19:31:07,791 - agents.data_agent - INFO - No local economic data, fetching full range
# 2025-12-22 19:31:08,106 - agents.data_agent - INFO - Fetched 12 data points for FEDFUNDS
# 2025-12-22 19:31:08,267 - agents.data_agent - INFO - Fetched 12 data points for CPIAUCSL
#
# ============================================================
# ✓ SUCCESS
# ============================================================
#
# Logs:
#   Date range: 2024-01-01 to 2024-12-19
#   === Fetching Stock Prices (Hourly) ===
#   Processing AAPL...
#     Saved 1700 hourly bars for AAPL
#   Processing MSFT...
#     Saved 1700 hourly bars for MSFT
#   Processing JPM...
#     Saved 1700 hourly bars for JPM
#   Processing XOM...
#     Saved 1700 hourly bars for XOM
#   Processing JNJ...
#     Saved 1700 hourly bars for JNJ
#   === Fetching Market Indices (Hourly) ===
#   Processing SPY...
#     Saved 1700 hourly bars for SPY
#   Processing QQQ...
#     Saved 1700 hourly bars for QQQ
#   Processing IWM...
#     Saved 1700 hourly bars for IWM
#   Processing VIX...
#     Saved 1465 hourly bars for VIX
#   === Fetching Sector ETFs (Hourly) ===
#   Processing XLK (Technology)...
#     Saved 1700 hourly bars for XLK
#   Processing XLF (Financial Services)...
#     Saved 1700 hourly bars for XLF
#   Processing XLE (Energy)...
#     Saved 1700 hourly bars for XLE
#   Processing XLV (Healthcare)...
#     Saved 1700 hourly bars for XLV
#   === Fetching Fundamentals (Daily) ===
#   Fetching fundamentals for AAPL...
#   Fetching fundamentals for MSFT...
#   Fetching fundamentals for JPM...
#   Fetching fundamentals for XOM...
#   Fetching fundamentals for JNJ...
#   === Fetching Company Profiles (Monthly) ===
#   Fetching company profile for AAPL...
#   Fetching company profile for MSFT...
#   Fetching company profile for JPM...
#   Fetching company profile for XOM...
#   Fetching company profile for JNJ...
#   === Fetching Economic Indicators ===
#   Indicators: ['FEDFUNDS', 'CPIAUCSL']
#     Resampled economic data to hourly (1700 rows)
#     Saved 1700 rows of economic data
#   === Generating Data Dictionary ===
#   Data dictionary saved to ./test_data/data_dictionary.json
#   === Data Collection Complete ===
#
# Data paths:
#   price_data: {'AAPL': './test_data/price_data/AAPL.parquet', 'MSFT': './test_data/price_data/MSFT.parquet', 'JPM': './test_data/price_data/JPM.parquet', 'XOM': './test_data/price_data/XOM.parquet', 'JNJ': './test_data/price_data/JNJ.parquet'}
#   market_data: {'SPY': './test_data/market_data/SPY.parquet', 'QQQ': './test_data/market_data/QQQ.parquet', 'IWM': './test_data/market_data/IWM.parquet', 'VIX': './test_data/market_data/VIX.parquet', 'XLK': './test_data/market_data/XLK.parquet', 'XLF': './test_data/market_data/XLF.parquet', 'XLE': './test_data/market_data/XLE.parquet', 'XLV': './test_data/market_data/XLV.parquet'}
#   company_profiles: {'AAPL': './test_data/company_profiles/AAPL.json', 'MSFT': './test_data/company_profiles/MSFT.json', 'JPM': './test_data/company_profiles/JPM.json', 'XOM': './test_data/company_profiles/XOM.json', 'JNJ': './test_data/company_profiles/JNJ.json'}
#   fundamentals: {'AAPL': './test_data/fundamentals/AAPL.json', 'MSFT': './test_data/fundamentals/MSFT.json', 'JPM': './test_data/fundamentals/JPM.json', 'XOM': './test_data/fundamentals/XOM.json', 'JNJ': './test_data/fundamentals/JNJ.json'}
#   economic_indicators: {'path': './test_data/economic/indicators.parquet', 'indicators': ['FEDFUNDS', 'CPIAUCSL']}
#   sector_etfs: {'XLK': './test_data/market_data/XLK.parquet', 'XLF': './test_data/market_data/XLF.parquet', 'XLE': './test_data/market_data/XLE.parquet', 'XLV': './test_data/market_data/XLV.parquet'}

# %%
import pandas as pd

# Read parquet file
df = pd.read_parquet("./test_data/price_data/AAPL.parquet")

# %%
df = pd.read_parquet("./test_data/economic/indicators.parquet")

# %%
df = pd.read_parquet("./test_data/market_data/SPY.parquet")

# %%
df.index
# Out:
# DatetimeIndex(['2024-01-02 09:30:00-05:00', '2024-01-02 10:30:00-05:00',
#                '2024-01-02 11:30:00-05:00', '2024-01-02 12:30:00-05:00',
#                '2024-01-02 13:30:00-05:00', '2024-01-02 14:30:00-05:00',
#                '2024-01-02 15:30:00-05:00', '2024-01-03 09:30:00-05:00',
#                '2024-01-03 10:30:00-05:00', '2024-01-03 11:30:00-05:00',
#                ...
#                '2024-12-17 13:30:00-05:00', '2024-12-17 14:30:00-05:00',
#                '2024-12-17 15:30:00-05:00', '2024-12-18 09:30:00-05:00',
#                '2024-12-18 10:30:00-05:00', '2024-12-18 11:30:00-05:00',
#                '2024-12-18 12:30:00-05:00', '2024-12-18 13:30:00-05:00',
#                '2024-12-18 14:30:00-05:00', '2024-12-18 15:30:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Datetime', length=1700, freq=None)

# %%
python test/test_quant_mcp_agent.py

# %% [markdown]
# test feature agent

# %%
# !python test/test_feature_agent.py
# Out:
# INFO - numexpr.utils - NumExpr defaulting to 8 threads.
# ============================================================
# Testing Feature Agent - Full Test
# ============================================================
# INFO - agents.feature_agent - Loaded data dictionary
# INFO - agents.feature_agent - Feature Agent initialized with 20 registered tools
# ✓ Agent initialized
#
# === Available Tools ===
#   independent: ['compute_log_return_y', 'compute_return_1h', 'compute_return_5h', 'compute_return', 'compute_rsi', 'compute_volatility', 'compute_macd', 'compute_macd_signal', 'compute_macd_hist', 'compute_volume_ratio', 'compute_price_range', 'compute_sector_return']
#   shared: ['compute_spy_return', 'compute_vix_level', 'compute_qqq_return', 'compute_iwm_return', 'compute_fed_rate', 'compute_cpi']
#   embedding: ['compute_text_embedding', 'compute_company_embedding']
#
# === Running Feature Engineering ===
# Tickers: ['AAPL', 'JNJ']
# INFO - agents.feature_agent -   Computed compute_log_return_y for AAPL
# INFO - agents.feature_agent -   Computed compute_return_1h for AAPL
# INFO - agents.feature_agent -   Computed compute_return_5h for AAPL
# INFO - agents.feature_agent -   Computed compute_rsi for AAPL
# INFO - agents.feature_agent -   Computed compute_volatility for AAPL
# INFO - agents.feature_agent -   Computed compute_macd for AAPL
# INFO - agents.feature_agent -   Computed compute_macd_signal for AAPL
# INFO - agents.feature_agent -   Computed compute_macd_hist for AAPL
# INFO - agents.feature_agent -   Computed compute_volume_ratio for AAPL
# INFO - agents.feature_agent -   Computed compute_price_range for AAPL
# INFO - agents.feature_agent -   Computed compute_sector_return for AAPL
# INFO - agents.feature_agent -   Computed compute_log_return_y for JNJ
# INFO - agents.feature_agent -   Computed compute_return_1h for JNJ
# INFO - agents.feature_agent -   Computed compute_return_5h for JNJ
# INFO - agents.feature_agent -   Computed compute_rsi for JNJ
# INFO - agents.feature_agent -   Computed compute_volatility for JNJ
# INFO - agents.feature_agent -   Computed compute_macd for JNJ
# INFO - agents.feature_agent -   Computed compute_macd_signal for JNJ
# INFO - agents.feature_agent -   Computed compute_macd_hist for JNJ
# INFO - agents.feature_agent -   Computed compute_volume_ratio for JNJ
# INFO - agents.feature_agent -   Computed compute_price_range for JNJ
# INFO - agents.feature_agent -   Computed compute_sector_return for JNJ
# INFO - agents.feature_agent -   Computed compute_spy_return
# INFO - agents.feature_agent -   Computed compute_vix_level
# INFO - agents.feature_agent -   Computed compute_qqq_return
# INFO - agents.feature_agent -   Computed compute_iwm_return
# INFO - agents.feature_agent -   Computed compute_fed_rate
# INFO - agents.feature_agent -   Computed compute_cpi
# INFO - httpx - HTTP Request: POST https://inference-api.alcf.anl.gov/resource_server/sophia/vllm/v1/embeddings "HTTP/1.1 400 Bad Request"
# ERROR - agents.factor_formulas - Error generating embedding: Error code: 400 - Error: The requested endpoint sophia-vllm-none does not exist.
# INFO - agents.factor_formulas - Falling back to local embedding model...
# INFO - sentence_transformers.SentenceTransformer - Use pytorch device_name: mps
# INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  2.68it/s]
# INFO - agents.factor_formulas - Generated local embedding: 384 dimensions
# INFO - agents.feature_agent -   Computed embedding for AAPL
# INFO - httpx - HTTP Request: POST https://inference-api.alcf.anl.gov/resource_server/sophia/vllm/v1/embeddings "HTTP/1.1 400 Bad Request"
# ERROR - agents.factor_formulas - Error generating embedding: Error code: 400 - Error: The requested endpoint sophia-vllm-none does not exist.
# INFO - agents.factor_formulas - Falling back to local embedding model...
# INFO - sentence_transformers.SentenceTransformer - Use pytorch device_name: mps
# INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 57.06it/s]
# INFO - agents.factor_formulas - Generated local embedding: 384 dimensions
# INFO - agents.feature_agent -   Computed embedding for JNJ
#
# ============================================================
# ✓ FEATURE ENGINEERING SUCCESS
# ============================================================
#
# Execution Logs:
#   === Determining Tools to Use ===
#   Selected 18 tools: ['compute_log_return_y', 'compute_return_1h', 'compute_return_5h', 'compute_rsi', 'compute_volatility', 'compute_macd', 'compute_macd_signal', 'compute_macd_hist', 'compute_volume_ratio', 'compute_price_range', 'compute_sector_return', 'compute_spy_return', 'compute_vix_level', 'compute_qqq_return', 'compute_iwm_return', 'compute_fed_rate', 'compute_cpi', 'compute_company_embedding']
#   === Checking Tool Requirements ===
#   Requirements: {'price_data': {'columns': {'High', 'Volume', 'Open', 'Low', 'Close'}}, 'market_data': {'tickers': {'SPY', 'VIX', 'QQQ', 'IWM'}, 'columns': {'Close'}}, 'economic': {'columns': {'FEDFUNDS', 'CPIAUCSL'}}, 'company_profiles': {'columns': {'sector', 'industry', 'company_name', 'business_summary'}}}
#   === Checking Data Availability ===
#   Available: ["price_data: {'High', 'Volume', 'Open', 'Low', 'Close'}", "market_data: {'SPY', 'VIX', 'QQQ', 'IWM'}", "economic: {'FEDFUNDS', 'CPIAUCSL'}", "company_profiles: {'sector', 'industry', 'company_name', 'business_summary'}"]
#   === Computing Independent Factors ===
#   Processing AAPL...
#     Saved 11 factors for AAPL
#   Processing JNJ...
#     Saved 11 factors for JNJ
#   === Computing Shared Factors ===
#     Saved 6 shared factors
#   === Computing Embeddings ===
#     Saved embeddings for 2 tickers
#   === Generating Feature Dictionary ===
#   Feature dictionary saved to ./test_data/features/feature_dictionary.json
#   === Feature Engineering Complete ===
#
# Output Paths:
#   independent_factors:
#     AAPL: ./test_data/features/independent_factors/AAPL.parquet
#     JNJ: ./test_data/features/independent_factors/JNJ.parquet
#   shared_factors_path: ./test_data/features/shared_factors.parquet
#   embeddings:
#     AAPL: ./test_data/features/embeddings/AAPL.npy
#     JNJ: ./test_data/features/embeddings/JNJ.npy
#
# === Verifying Output Files ===
#
# Independent Factors (per ticker):
#   ✓ AAPL: 1700 rows, 11 factors
#       Columns: ['compute_log_return_y', 'compute_return_1h', 'compute_return_5h', 'compute_rsi', 'compute_volatility', 'compute_macd', 'compute_macd_signal', 'compute_macd_hist', 'compute_volume_ratio', 'compute_price_range', 'compute_sector_return']
#   ✓ JNJ: 1700 rows, 11 factors
#       Columns: ['compute_log_return_y', 'compute_return_1h', 'compute_return_5h', 'compute_rsi', 'compute_volatility', 'compute_macd', 'compute_macd_signal', 'compute_macd_hist', 'compute_volume_ratio', 'compute_price_range', 'compute_sector_return']
#
# Shared Factors:
#   ✓ shared_factors: 1700 rows
#       Columns: ['compute_spy_return', 'compute_vix_level', 'compute_qqq_return', 'compute_iwm_return', 'compute_fed_rate', 'compute_cpi']
#
# Embeddings:
#   ✓ AAPL embedding: shape=(384,), norm=1.0000
#   ✓ JNJ embedding: shape=(384,), norm=1.0000
#
# Feature Dictionary:
#   ✓ feature_dictionary.json
#       Tickers: ['AAPL', 'JNJ']
#       Tools used: 18
#       Embeddings: False
#
# ============================================================
# FINAL RESULT: ✓ PASS
# ============================================================

# %%
import numpy as np
data = np.load('./test_data/features/embeddings/AAPL.npy')

# %%
data
# Out:
# array([-4.27563153e-02, -3.79214324e-02, -2.18351744e-02, -5.47887832e-02,
#         7.14211836e-02,  4.85546626e-02,  7.11484030e-02, -3.13218832e-02,
#         7.10915551e-02, -2.76945997e-02,  6.66946918e-02, -6.75039599e-03,
#         2.16772277e-02, -3.75372842e-02,  1.45346284e-01, -8.17118734e-02,
#         5.87109737e-02, -9.65703186e-03, -3.52783315e-02, -1.87055152e-02,
#        -2.54782047e-02,  4.17536683e-02,  2.91265808e-02,  8.83927420e-02,
#        -4.33882363e-02,  7.88740590e-02, -4.24614288e-02,  7.84546323e-03,
#        -6.69855177e-02, -1.60527322e-02,  2.47622337e-02, -2.57423557e-02,
#         1.09169766e-01,  1.93330441e-02, -1.80286616e-02, -4.51097973e-02,
#        -2.42515188e-02, -4.54572812e-02, -1.10947214e-01, -3.29986550e-02,
#        -6.23198822e-02, -6.57637045e-03, -1.23777688e-02,  1.02020085e-01,
#         4.73600551e-02, -1.11533469e-02, -2.71538179e-02,  1.84708852e-02,
#         3.40467393e-02,  1.65404260e-01, -8.53998773e-03, -5.85915633e-02,
#         5.00661917e-02,  2.73600612e-02, -7.20206834e-03,  4.12909985e-02,
#        -3.14168073e-02,  1.14360042e-02,  6.43196106e-02,  2.76493691e-02,
#         1.02361463e-01, -1.01670220e-01,  4.96107265e-02,  5.17911650e-02,
#        -1.19139403e-02, -3.25998291e-02, -1.96274202e-02,  5.76797351e-02,
#         5.99568663e-03, -8.62274319e-02,  2.87523586e-02, -4.66227420e-02,
#         8.35371539e-02,  8.54336843e-02,  1.48935243e-02,  4.72185723e-02,
#         3.79797406e-02, -5.88595681e-02, -1.26195978e-02,  2.12893859e-02,
#        -1.02091007e-01,  1.95390731e-02, -8.04040208e-03,  9.52041009e-04,
#         5.92702348e-03, -1.71948839e-02, -4.25713956e-02, -3.14990394e-02,
#        -4.08883691e-02,  2.24125255e-02, -6.79282248e-02,  4.51472215e-02,
#         1.64790184e-03, -3.94959599e-02,  3.30997892e-02, -1.41731724e-02,
#        -3.43769193e-02, -7.56756589e-02, -2.99156941e-02, -1.34546738e-02,
#        -4.33219504e-03,  8.38042870e-02,  4.98504676e-02,  5.25936373e-02,
#         1.22185014e-02, -1.36525795e-01, -6.65326715e-02,  4.96465489e-02,
#         8.40874538e-02,  1.72761112e-01,  2.16084924e-02, -5.08600175e-02,
#        -2.86451913e-02, -3.58362757e-02,  5.88102788e-02,  8.85467455e-02,
#        -1.90185197e-02,  8.08369741e-02,  1.10993750e-01,  6.26649894e-03,
#        -1.17546674e-02,  7.41481334e-02,  5.26282713e-02, -6.56271726e-02,
#        -3.34067531e-02,  1.03572663e-02, -3.85633484e-02, -2.55888682e-33,
#        -9.33777243e-02,  2.09613685e-02,  2.62319278e-02, -1.06705981e-03,
#        -1.20897740e-02, -7.24259168e-02, -1.45126483e-03,  6.79862872e-02,
#         3.71062532e-02,  7.92928785e-02, -7.02947155e-02,  6.04729913e-02,
#         8.29035509e-03,  7.22295716e-02,  5.19962125e-02, -4.09378409e-02,
#        -8.31956565e-02, -4.15393375e-02,  2.92551629e-02,  1.40699418e-02,
#         1.12435753e-02, -4.23749983e-02,  7.96886161e-03,  5.98733500e-02,
#        -1.56545714e-02, -3.39043178e-02,  4.42843363e-02, -1.39471563e-02,
#         8.63163844e-02, -8.57692491e-03,  1.04517052e-02, -5.22348583e-02,
#         7.08631333e-03, -1.10101640e-01, -3.79118286e-02, -3.85694169e-02,
#        -1.22603180e-03, -3.32629234e-02,  3.23072821e-02,  3.60912941e-02,
#        -7.94969946e-02, -5.88383712e-02, -6.11143634e-02, -2.48343609e-02,
#         2.06913874e-02, -5.90546057e-03,  1.53172556e-02, -4.31322604e-02,
#        -3.59399132e-02,  2.54517123e-02, -6.18972220e-02, -1.34379081e-02,
#         1.72139611e-02, -6.44682646e-02, -1.91283133e-02,  1.57631151e-02,
#         3.00299190e-03, -4.06816602e-02, -1.87285598e-02,  2.44964547e-02,
#        -5.49867600e-02, -3.31686959e-02,  4.45557050e-02,  2.35683303e-02,
#        -8.96846130e-02,  6.21085949e-02,  9.20279324e-02, -7.87206739e-02,
#        -4.44340222e-02,  7.81418383e-02, -2.89612653e-04,  6.93235844e-02,
#         1.42150084e-02, -1.68604814e-02, -7.45061561e-02,  2.15516184e-02,
#        -6.25292137e-02, -2.34300699e-02, -5.77949621e-02,  2.87683066e-02,
#        -2.75471378e-02,  1.92454010e-02,  3.99990715e-02,  6.45528287e-02,
#        -3.74143906e-02,  4.39674370e-02, -1.40045024e-02, -5.19208536e-02,
#        -9.13952757e-03, -3.08078956e-02, -7.29333907e-02,  1.00396603e-01,
#        -3.70917879e-02,  6.27255738e-02, -4.04073717e-03,  9.68023455e-34,
#        -1.01526687e-02, -6.20340705e-02,  1.15384096e-02, -5.78218848e-02,
#        -7.91305397e-03, -6.15647389e-03, -1.98515616e-02,  2.80986987e-02,
#        -2.35345535e-04,  1.08339237e-02, -7.09725767e-02,  1.66303590e-02,
#        -1.92278270e-02,  2.46603806e-02, -3.25385965e-02,  5.12848906e-02,
#        -8.78505930e-02, -6.71580061e-02,  3.35440552e-03,  3.00883297e-02,
#         9.58790537e-03,  1.50330300e-02,  7.46324137e-02, -3.42593826e-02,
#         2.83465516e-02, -4.61989231e-02, -7.92097021e-03,  3.37311104e-02,
#         8.08330402e-02,  1.40952123e-02,  3.06312516e-02, -8.91456977e-02,
#        -1.23319933e-02, -8.50065053e-03,  7.63858184e-02,  5.80531405e-03,
#        -3.83963846e-02,  5.34540452e-02, -2.01258692e-03, -2.19673403e-02,
#         5.46285771e-02, -3.38958278e-02, -4.19971347e-03, -3.82631761e-03,
#         1.61566120e-02,  2.10348237e-02,  9.18180775e-03,  5.89163974e-02,
#         2.83311624e-02, -5.23732454e-02, -2.52560861e-02, -3.18336040e-02,
#        -1.94816310e-02,  1.26517033e-02, -7.14427978e-02,  6.37643188e-02,
#        -1.29189165e-02,  5.87150753e-02, -4.36730795e-02, -2.68158205e-02,
#         3.02263871e-02, -1.58183202e-02,  2.77841613e-02, -2.09497418e-02,
#        -2.04158518e-02, -1.97461396e-02,  4.59952876e-02,  2.12193318e-02,
#        -1.07386038e-02,  2.97097992e-02, -1.18082529e-03, -2.40261178e-03,
#        -1.00642187e-03, -6.96806535e-02, -9.61436480e-02,  2.27425992e-02,
#         1.67242810e-02, -4.68358919e-02, -5.72003908e-02, -4.62267697e-02,
#         5.60103841e-02,  9.01048332e-02,  7.56087378e-02,  3.11969165e-02,
#         2.94457693e-02,  2.19061854e-03,  5.77558428e-02, -2.06173584e-02,
#        -5.81022799e-02,  3.95653285e-02, -5.93513902e-03,  5.43703325e-02,
#        -1.36294439e-01,  7.88014755e-02, -9.89978984e-02, -4.63772416e-08,
#         7.45603582e-03, -5.93381189e-02,  3.86305451e-02, -2.77017951e-02,
#         5.02808532e-03,  4.86243330e-03,  6.48793299e-03, -4.95965853e-02,
#         1.14946954e-01, -1.80388689e-02, -5.27826231e-03, -4.72733155e-02,
#        -1.37612313e-01,  4.11804840e-02, -1.34804677e-02,  1.44494679e-02,
#        -5.52364103e-02,  4.62643355e-02,  2.12606099e-02, -4.76584164e-03,
#        -2.84299478e-02,  6.11226894e-02,  1.44721929e-03, -3.34709920e-02,
#        -1.68560538e-02,  4.04694229e-02,  4.03564945e-02, -1.58259831e-02,
#         6.41865879e-02,  3.19738733e-03, -1.78338178e-02, -9.92763788e-03,
#         8.65516532e-03, -5.15252687e-02, -2.84539126e-02, -1.11341245e-01,
#         8.30902904e-02, -2.55159079e-03, -2.44955700e-02,  3.30889337e-02,
#        -6.11267537e-02, -6.60479739e-02, -3.35195358e-03, -2.30069719e-02,
#        -3.33585069e-02, -5.60684763e-02, -3.10235191e-02, -5.04816361e-02,
#         6.63957372e-02,  8.48924890e-02, -9.72323027e-03, -3.60825658e-02,
#         1.03501789e-01,  1.41746858e-02, -5.05350642e-02,  2.40399688e-02,
#         3.81070413e-02, -1.11576647e-01,  8.90481006e-03,  1.12801887e-01,
#         5.92404790e-02, -5.95387444e-02,  1.07649006e-01,  2.76338328e-02],
#       dtype=float32)

# %%
import pandas as pd
df = pd.read_parquet('./test_data/features/independent_factors/AAPL.parquet')

# %%
import pandas as pd
df = pd.read_parquet('./test_data/features/shared_factors.parquet')

# %%
df
# Out:
#                            compute_log_return_y  compute_return_1h  \
# Datetime
# 2024-01-02 09:30:00-05:00             -0.008616                NaN
# 2024-01-02 10:30:00-05:00              0.003351           0.003298
# 2024-01-02 11:30:00-05:00             -0.000991          -0.001018
# 2024-01-02 12:30:00-05:00             -0.007099          -0.007099
# 2024-01-02 13:30:00-05:00             -0.004300          -0.004327
# ...                                         ...                ...
# 2024-12-18 11:30:00-05:00              0.001229           0.001243
# 2024-12-18 12:30:00-05:00              0.000316           0.000296
# 2024-12-18 13:30:00-05:00             -0.004939          -0.004979
# 2024-12-18 14:30:00-05:00             -0.010148          -0.010152
# 2024-12-18 15:30:00-05:00             -0.008277          -0.008197
#
#                            compute_return_5h  compute_rsi  compute_volatility  \
# Datetime
# 2024-01-02 09:30:00-05:00                NaN          NaN                 NaN
# 2024-01-02 10:30:00-05:00                NaN          NaN                 NaN
# 2024-01-02 11:30:00-05:00                NaN          NaN                 NaN
# 2024-01-02 12:30:00-05:00                NaN          NaN                 NaN
# 2024-01-02 13:30:00-05:00                NaN          NaN                 NaN
# ...                                      ...          ...                 ...
# 2024-12-18 11:30:00-05:00           0.001717    79.521291            0.001837
# 2024-12-18 12:30:00-05:00           0.003277    75.591273            0.001808
# 2024-12-18 13:30:00-05:00          -0.004072    63.680231            0.002269
# 2024-12-18 14:30:00-05:00          -0.012605    45.309743            0.003355
# 2024-12-18 15:30:00-05:00          -0.021789    34.366073            0.003758
#
#                            compute_macd  compute_macd_signal  \
# Datetime
# 2024-01-02 09:30:00-05:00      0.000000             0.000000
# 2024-01-02 10:30:00-05:00      0.049068             0.009814
# 2024-01-02 11:30:00-05:00      0.071796             0.022210
# 2024-01-02 12:30:00-05:00     -0.016515             0.014465
# 2024-01-02 13:30:00-05:00     -0.149334            -0.018295
# ...                                 ...                  ...
# 2024-12-18 11:30:00-05:00      1.490114             1.408609
# 2024-12-18 12:30:00-05:00      1.472984             1.421484
# 2024-12-18 13:30:00-05:00      1.342256             1.405638
# 2024-12-18 14:30:00-05:00      1.021118             1.328734
# 2024-12-18 15:30:00-05:00      0.595143             1.182016
#
#                            compute_macd_hist  compute_volume_ratio  \
# Datetime
# 2024-01-02 09:30:00-05:00           0.000000                   NaN
# 2024-01-02 10:30:00-05:00           0.039254                   NaN
# 2024-01-02 11:30:00-05:00           0.049586                   NaN
# 2024-01-02 12:30:00-05:00          -0.030980                   NaN
# 2024-01-02 13:30:00-05:00          -0.131039                   NaN
# ...                                      ...                   ...
# 2024-12-18 11:30:00-05:00           0.081506              0.815656
# 2024-12-18 12:30:00-05:00           0.051500              0.599360
# 2024-12-18 13:30:00-05:00          -0.063383              1.057627
# 2024-12-18 14:30:00-05:00          -0.307616              1.761055
# 2024-12-18 15:30:00-05:00          -0.586873              1.890501
#
#                            compute_price_range  compute_sector_return
# Datetime
# 2024-01-02 09:30:00-05:00             0.012939                    NaN
# 2024-01-02 10:30:00-05:00             0.009242               0.002982
# 2024-01-02 11:30:00-05:00             0.004176              -0.000425
# 2024-01-02 12:30:00-05:00             0.009538              -0.002503
# 2024-01-02 13:30:00-05:00             0.007070              -0.001975
# ...                                        ...                    ...
# 2024-12-18 11:30:00-05:00             0.003415               0.000456
# 2024-12-18 12:30:00-05:00             0.002129               0.000083
# 2024-12-18 13:30:00-05:00             0.010800              -0.010253
# 2024-12-18 14:30:00-05:00             0.013785              -0.016132
# 2024-12-18 15:30:00-05:00             0.010600              -0.011174
#
# [1700 rows x 11 columns]

# %%
import json
profile = json.load(open("./test_data/company_profiles/AAPL.json"))

# %%
profile
# Out:
# {'ticker': 'AAPL',
#  'company_name': 'Apple Inc.',
#  'sector': 'Technology',
#  'industry': 'Consumer Electronics',
#  'business_summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'website': 'https://www.apple.com',
#  'country': 'United States',
#  'employees': 166000,
#  'fetched_at': '2025-12-22 17:09:39'}
